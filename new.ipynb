# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import torch.nn as nn
import torch.nn.functional as F
from sklearn.decomposition import PCA       # Needed for PCA of embeddings
import os

device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("Using GPU", torch.cuda.get_device_name(0))
else:
    print("Using CPU")
# Out:
# Using CPU

# %%
SEED = 42

def set_seed(seed_value=0):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %%
# Prime number for modular addition
P = 53

# Create the dataset
set_seed(SEED)
data = []
for i in range(P):
    for j in range(P):
        data.append([i,j,(i+j)%P])
data = np.array(data)

# Split into train and test
TRAIN_FRACTION = 0.5
np.random.shuffle(data)
train_data = data[:int(len(data) * TRAIN_FRACTION)]
test_data = data[int(len(data) * TRAIN_FRACTION):]

# Convert to tensors and create dataloaders with batch size
BATCH_SIZE = 32
train_data = torch.tensor(train_data, dtype=torch.long, device=device)
test_data = torch.tensor(test_data, dtype=torch.long, device=device)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

D_EMBED = 128
HIDDEN = 256
P = 59

class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()
        self.embed = nn.Embedding(P, D_EMBED)
        self.rnn = nn.RNN(input_size=D_EMBED, hidden_size=HIDDEN, batch_first=True)
        self.linear = nn.Linear(HIDDEN, P)
        self.init_weights()

    def forward(self, x1, x2):
        x1 = self.embed(x1)
        x2 = self.embed(x2)
        x = torch.stack((x1, x2), dim=1)
        _, h_n = self.rnn(x)
        x = self.linear(h_n.squeeze(0))
        return x

    # Weight initialization
    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Embedding):
                nn.init.xavier_normal_(m.weight)
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)

# %%
NB_EPOCHS = 5000
LEARNING_RATE = 0.0003
WEIGHT_DECAY = 1

set_seed(SEED)
model = RNN().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# Recording
REPORT_INTERVAL = 20    # How often we print
SAVE_INTERVAL = 50      # How often we save
model_folder = 'intermediary'
# Create folder if it doesn't exist
if not os.path.exists(model_folder):
    os.makedirs(model_folder)

train_loss_history = []
train_acc_history = []
test_loss_history = []
test_acc_history = []

for epoch in range(NB_EPOCHS):
    
    # Training phase
    model.train()
    train_loss = 0.0
    train_acc = 0.0
    for batch in train_loader:
        x1, x2, y = batch[:,0], batch[:,1], batch[:,2]
        optimizer.zero_grad()
        output = model(x1,x2)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (output.argmax(dim=1) == y).sum().item()
        
    train_loss /= len(train_loader)
    train_loss_history.append(train_loss)
    train_acc /= len(train_data)
    train_acc_history.append(train_acc)
    
    # Testing phase
    model.eval()
    with torch.no_grad():
        test_loss = 0.0
        test_acc = 0.0
        for batch in test_loader:
            x1, x2, y = batch[:,0], batch[:,1], batch[:,2]
            output = model(x1,x2)
            loss = criterion(output, y)
            test_loss += loss.item()
            test_acc += (output.argmax(dim=1) == y).sum().item()
        
        test_loss /= len(test_loader)
        test_loss_history.append(test_loss)
        test_acc /= len(test_data)
        test_acc_history.append(test_acc)
        
    if epoch % REPORT_INTERVAL == 0:
        print(f"{epoch}/{NB_EPOCHS}: Train loss={train_loss:.4f}, acc={100*train_acc:.1f}%  /  Test loss={test_loss:.4f}, acc={100*test_acc:.1f}%")
    
    if epoch % SAVE_INTERVAL == 0:
        # Save model in intermediary folder
        torch.save(model.state_dict(), f"{model_folder}/model_{epoch}.pth")
        
torch.save(model.state_dict(), f"model.pth")
# Out:
# 0/5000: Train loss=4.0707, acc=0.9%  /  Test loss=4.0608, acc=1.6%
# 20/5000: Train loss=3.6826, acc=6.4%  /  Test loss=4.4905, acc=0.0%
# 40/5000: Train loss=3.4797, acc=7.0%  /  Test loss=5.0123, acc=0.0%
# 60/5000: Train loss=3.4112, acc=8.5%  /  Test loss=5.1950, acc=0.0%
# 80/5000: Train loss=3.3849, acc=8.3%  /  Test loss=5.2611, acc=0.0%
# 100/5000: Train loss=3.3739, acc=8.0%  /  Test loss=5.2920, acc=0.0%
# 120/5000: Train loss=3.3670, acc=7.5%  /  Test loss=5.3152, acc=0.0%
# 140/5000: Train loss=3.3621, acc=7.8%  /  Test loss=5.3320, acc=0.0%
# 160/5000: Train loss=3.3597, acc=7.4%  /  Test loss=5.3472, acc=0.0%
# 180/5000: Train loss=3.3562, acc=7.1%  /  Test loss=5.3566, acc=0.0%
# 200/5000: Train loss=3.3535, acc=7.6%  /  Test loss=5.3685, acc=0.0%
# 220/5000: Train loss=3.3525, acc=8.1%  /  Test loss=5.3783, acc=0.0%
# 240/5000: Train loss=3.3487, acc=8.0%  /  Test loss=5.3889, acc=0.0%
# 260/5000: Train loss=3.3456, acc=7.5%  /  Test loss=5.3974, acc=0.0%
# 280/5000: Train loss=3.3405, acc=8.0%  /  Test loss=5.4089, acc=0.0%
# 300/5000: Train loss=3.3388, acc=8.3%  /  Test loss=5.4177, acc=0.0%
# 320/5000: Train loss=3.3348, acc=7.7%  /  Test loss=5.4237, acc=0.0%
# 340/5000: Train loss=3.3326, acc=7.8%  /  Test loss=5.4341, acc=0.0%
# 360/5000: Train loss=3.3275, acc=8.1%  /  Test loss=5.4421, acc=0.0%
# 380/5000: Train loss=3.3252, acc=7.7%  /  Test loss=5.4519, acc=0.0%
# 400/5000: Train loss=3.3207, acc=8.2%  /  Test loss=5.4611, acc=0.0%
# 420/5000: Train loss=3.3168, acc=8.2%  /  Test loss=5.4719, acc=0.0%
# 440/5000: Train loss=3.3142, acc=8.3%  /  Test loss=5.4792, acc=0.0%
# 460/5000: Train loss=3.3095, acc=7.5%  /  Test loss=5.4886, acc=0.0%
# 480/5000: Train loss=3.3046, acc=8.2%  /  Test loss=5.4991, acc=0.0%
# 500/5000: Train loss=3.3005, acc=8.4%  /  Test loss=5.5101, acc=0.0%
# 520/5000: Train loss=3.2947, acc=8.5%  /  Test loss=5.5168, acc=0.0%
# 540/5000: Train loss=3.2908, acc=8.5%  /  Test loss=5.5258, acc=0.0%
# 560/5000: Train loss=3.2859, acc=8.6%  /  Test loss=5.5381, acc=0.0%
# 580/5000: Train loss=3.2813, acc=8.2%  /  Test loss=5.5476, acc=0.0%
# 600/5000: Train loss=3.2751, acc=8.8%  /  Test loss=5.5590, acc=0.0%
# 620/5000: Train loss=3.2696, acc=8.5%  /  Test loss=5.5685, acc=0.0%
# 640/5000: Train loss=3.2639, acc=9.0%  /  Test loss=5.5807, acc=0.0%
# 660/5000: Train loss=3.2582, acc=9.3%  /  Test loss=5.5906, acc=0.0%
# 680/5000: Train loss=3.2523, acc=10.1%  /  Test loss=5.6035, acc=0.0%
# 700/5000: Train loss=3.2445, acc=10.1%  /  Test loss=5.6173, acc=0.0%
# 720/5000: Train loss=3.2386, acc=9.8%  /  Test loss=5.6286, acc=0.0%
# 740/5000: Train loss=3.2305, acc=10.3%  /  Test loss=5.6411, acc=0.0%
# 760/5000: Train loss=3.2242, acc=10.4%  /  Test loss=5.6511, acc=0.0%
# 780/5000: Train loss=3.2175, acc=10.7%  /  Test loss=5.6651, acc=0.0%
# 800/5000: Train loss=3.2091, acc=11.1%  /  Test loss=5.6792, acc=0.0%
# 820/5000: Train loss=3.1997, acc=11.1%  /  Test loss=5.6931, acc=0.0%
# 840/5000: Train loss=3.1902, acc=10.8%  /  Test loss=5.7072, acc=0.0%
# 860/5000: Train loss=3.1817, acc=11.7%  /  Test loss=5.7211, acc=0.0%
# 880/5000: Train loss=3.1706, acc=12.0%  /  Test loss=5.7375, acc=0.0%
# 900/5000: Train loss=3.1603, acc=12.0%  /  Test loss=5.7523, acc=0.0%
# 920/5000: Train loss=3.1510, acc=12.8%  /  Test loss=5.7675, acc=0.0%
# 940/5000: Train loss=3.1387, acc=13.0%  /  Test loss=5.7839, acc=0.0%
# 960/5000: Train loss=3.1267, acc=13.9%  /  Test loss=5.7992, acc=0.0%
# 980/5000: Train loss=3.1141, acc=13.7%  /  Test loss=5.8170, acc=0.0%
# 1000/5000: Train loss=3.0998, acc=14.8%  /  Test loss=5.8312, acc=0.0%
# 1020/5000: Train loss=3.0863, acc=15.2%  /  Test loss=5.8485, acc=0.0%
# 1040/5000: Train loss=3.0701, acc=16.5%  /  Test loss=5.8690, acc=0.0%
# 1060/5000: Train loss=3.0540, acc=17.0%  /  Test loss=5.8838, acc=0.0%
# 1080/5000: Train loss=3.0379, acc=17.4%  /  Test loss=5.9036, acc=0.0%
# 1100/5000: Train loss=3.0180, acc=19.9%  /  Test loss=5.9222, acc=0.0%
# 1120/5000: Train loss=2.9981, acc=20.6%  /  Test loss=5.9419, acc=0.0%
# 1140/5000: Train loss=2.9787, acc=21.3%  /  Test loss=5.9625, acc=0.0%
# 1800/5000: Train loss=1.3143, acc=97.8%  /  Test loss=5.7514, acc=0.1%
# 1820/5000: Train loss=1.2553, acc=98.4%  /  Test loss=5.6999, acc=0.1%
# 1840/5000: Train loss=1.1974, acc=98.9%  /  Test loss=5.6488, acc=0.1%
# 1860/5000: Train loss=1.1413, acc=99.2%  /  Test loss=5.5972, acc=0.1%
# 1880/5000: Train loss=1.0869, acc=99.4%  /  Test loss=5.5429, acc=0.1%
# 1900/5000: Train loss=1.0342, acc=99.4%  /  Test loss=5.4880, acc=0.1%
# 1920/5000: Train loss=0.9834, acc=99.6%  /  Test loss=5.4415, acc=0.1%
# 1940/5000: Train loss=0.9358, acc=99.7%  /  Test loss=5.3925, acc=0.1%
# 1960/5000: Train loss=0.8882, acc=99.8%  /  Test loss=5.3436, acc=0.1%
# 1980/5000: Train loss=0.8450, acc=99.8%  /  Test loss=5.2962, acc=0.1%
# 2000/5000: Train loss=0.8033, acc=99.8%  /  Test loss=5.2504, acc=0.1%
# 2020/5000: Train loss=0.7625, acc=99.9%  /  Test loss=5.2023, acc=0.1%
# 2040/5000: Train loss=0.7235, acc=99.9%  /  Test loss=5.1550, acc=0.4%
# 2060/5000: Train loss=0.6868, acc=100.0%  /  Test loss=5.1070, acc=0.3%
# 2080/5000: Train loss=0.6510, acc=100.0%  /  Test loss=5.0570, acc=0.3%
# 2100/5000: Train loss=0.6178, acc=100.0%  /  Test loss=5.0085, acc=0.4%
# 2120/5000: Train loss=0.5838, acc=100.0%  /  Test loss=4.9581, acc=0.5%
# 2140/5000: Train loss=0.5542, acc=100.0%  /  Test loss=4.9067, acc=0.6%
# 2160/5000: Train loss=0.5244, acc=100.0%  /  Test loss=4.8591, acc=0.5%
# 2180/5000: Train loss=0.4957, acc=100.0%  /  Test loss=4.8099, acc=0.8%
# 2200/5000: Train loss=0.4688, acc=100.0%  /  Test loss=4.7590, acc=0.6%
# 2220/5000: Train loss=0.4442, acc=100.0%  /  Test loss=4.7114, acc=0.9%
# 2240/5000: Train loss=0.4201, acc=100.0%  /  Test loss=4.6668, acc=1.4%
# 2260/5000: Train loss=0.3973, acc=100.0%  /  Test loss=4.6207, acc=1.4%
# 2280/5000: Train loss=0.3764, acc=100.0%  /  Test loss=4.5731, acc=1.4%
# 2300/5000: Train loss=0.3561, acc=100.0%  /  Test loss=4.5279, acc=1.6%
# 2320/5000: Train loss=0.3377, acc=100.0%  /  Test loss=4.4815, acc=1.9%
# 2340/5000: Train loss=0.3195, acc=100.0%  /  Test loss=4.4368, acc=2.1%
# 2360/5000: Train loss=0.3030, acc=100.0%  /  Test loss=4.3907, acc=2.6%
# 2380/5000: Train loss=0.2868, acc=100.0%  /  Test loss=4.3437, acc=2.7%
# 2400/5000: Train loss=0.2713, acc=100.0%  /  Test loss=4.2961, acc=2.9%
# 2420/5000: Train loss=0.2564, acc=100.0%  /  Test loss=4.2477, acc=3.3%
# 2440/5000: Train loss=0.2428, acc=100.0%  /  Test loss=4.2023, acc=3.5%
# 2460/5000: Train loss=0.2293, acc=100.0%  /  Test loss=4.1515, acc=3.8%
# 2480/5000: Train loss=0.2168, acc=100.0%  /  Test loss=4.1024, acc=4.2%
# 2500/5000: Train loss=0.2050, acc=100.0%  /  Test loss=4.0553, acc=4.6%
# 2520/5000: Train loss=0.1933, acc=100.0%  /  Test loss=3.9995, acc=5.2%
# 2540/5000: Train loss=0.1824, acc=100.0%  /  Test loss=3.9494, acc=5.4%
# 2560/5000: Train loss=0.1720, acc=100.0%  /  Test loss=3.8991, acc=5.6%
# 2580/5000: Train loss=0.1624, acc=100.0%  /  Test loss=3.8469, acc=6.0%
# 2600/5000: Train loss=0.1533, acc=100.0%  /  Test loss=3.7967, acc=6.5%
# 2620/5000: Train loss=0.1442, acc=100.0%  /  Test loss=3.7481, acc=7.3%
# 2640/5000: Train loss=0.1366, acc=100.0%  /  Test loss=3.6985, acc=7.9%
# 2660/5000: Train loss=0.1284, acc=100.0%  /  Test loss=3.6514, acc=8.5%
# 2680/5000: Train loss=0.1210, acc=100.0%  /  Test loss=3.6018, acc=8.8%
# 2700/5000: Train loss=0.1139, acc=100.0%  /  Test loss=3.5506, acc=10.0%
# 2720/5000: Train loss=0.1076, acc=100.0%  /  Test loss=3.5052, acc=10.6%
# 2740/5000: Train loss=0.1016, acc=100.0%  /  Test loss=3.4586, acc=11.5%
# 2760/5000: Train loss=0.0960, acc=100.0%  /  Test loss=3.4108, acc=12.4%
# 2780/5000: Train loss=0.0904, acc=100.0%  /  Test loss=3.3634, acc=13.0%
# 2800/5000: Train loss=0.0853, acc=100.0%  /  Test loss=3.3186, acc=13.9%
# 2820/5000: Train loss=0.0803, acc=100.0%  /  Test loss=3.2705, acc=15.0%
# 2840/5000: Train loss=0.0757, acc=100.0%  /  Test loss=3.2216, acc=16.2%
# 2860/5000: Train loss=0.0713, acc=100.0%  /  Test loss=3.1781, acc=16.9%
# 2880/5000: Train loss=0.0673, acc=100.0%  /  Test loss=3.1275, acc=18.4%
# 2900/5000: Train loss=0.0633, acc=100.0%  /  Test loss=3.0824, acc=19.4%
# 2920/5000: Train loss=0.0599, acc=100.0%  /  Test loss=3.0380, acc=20.5%
# 2940/5000: Train loss=0.0565, acc=100.0%  /  Test loss=2.9915, acc=21.5%
# 2960/5000: Train loss=0.0532, acc=100.0%  /  Test loss=2.9441, acc=23.1%
# 2980/5000: Train loss=0.0501, acc=100.0%  /  Test loss=2.8999, acc=23.1%
# 3000/5000: Train loss=0.0471, acc=100.0%  /  Test loss=2.8518, acc=24.3%
# 3020/5000: Train loss=0.0445, acc=100.0%  /  Test loss=2.8033, acc=26.2%
# 3040/5000: Train loss=0.0419, acc=100.0%  /  Test loss=2.7589, acc=27.1%
# 3060/5000: Train loss=0.0394, acc=100.0%  /  Test loss=2.7112, acc=28.5%
# 3720/5000: Train loss=0.0068, acc=100.0%  /  Test loss=1.5538, acc=64.6%
# 3740/5000: Train loss=0.0065, acc=100.0%  /  Test loss=1.5279, acc=65.7%
# 3760/5000: Train loss=0.0062, acc=100.0%  /  Test loss=1.4995, acc=66.5%
# 3780/5000: Train loss=0.0059, acc=100.0%  /  Test loss=1.4729, acc=67.0%
# 3800/5000: Train loss=0.0056, acc=100.0%  /  Test loss=1.4509, acc=67.8%
# 3820/5000: Train loss=0.0054, acc=100.0%  /  Test loss=1.4251, acc=68.3%
# 3840/5000: Train loss=0.0052, acc=100.0%  /  Test loss=1.4020, acc=68.8%
# 3860/5000: Train loss=0.0049, acc=100.0%  /  Test loss=1.3804, acc=69.4%
# 3880/5000: Train loss=0.0047, acc=100.0%  /  Test loss=1.3553, acc=70.1%
# 3900/5000: Train loss=0.0045, acc=100.0%  /  Test loss=1.3321, acc=70.7%
# 3920/5000: Train loss=0.0043, acc=100.0%  /  Test loss=1.3121, acc=71.2%
# 3940/5000: Train loss=0.0041, acc=100.0%  /  Test loss=1.2892, acc=72.2%
# 3960/5000: Train loss=0.0040, acc=100.0%  /  Test loss=1.2700, acc=72.1%
# 3980/5000: Train loss=0.0038, acc=100.0%  /  Test loss=1.2490, acc=72.7%
# 4000/5000: Train loss=0.0036, acc=100.0%  /  Test loss=1.2290, acc=73.3%
# 4020/5000: Train loss=0.0035, acc=100.0%  /  Test loss=1.2079, acc=74.7%
# 4040/5000: Train loss=0.0034, acc=100.0%  /  Test loss=1.1917, acc=74.9%
# 4060/5000: Train loss=0.0032, acc=100.0%  /  Test loss=1.1732, acc=75.3%
# 4080/5000: Train loss=0.0031, acc=100.0%  /  Test loss=1.1530, acc=76.0%
# 4100/5000: Train loss=0.0030, acc=100.0%  /  Test loss=1.1348, acc=76.4%
# 4120/5000: Train loss=0.0029, acc=100.0%  /  Test loss=1.1180, acc=77.0%
# 4140/5000: Train loss=0.0027, acc=100.0%  /  Test loss=1.1001, acc=76.9%
# 4160/5000: Train loss=0.0026, acc=100.0%  /  Test loss=1.0847, acc=77.5%
# 4180/5000: Train loss=0.0026, acc=100.0%  /  Test loss=1.0688, acc=78.1%
# 4200/5000: Train loss=0.0025, acc=100.0%  /  Test loss=1.0537, acc=78.3%
# 4220/5000: Train loss=0.0024, acc=100.0%  /  Test loss=1.0366, acc=79.1%
# 4240/5000: Train loss=0.0023, acc=100.0%  /  Test loss=1.0235, acc=79.5%
# 4260/5000: Train loss=0.0022, acc=100.0%  /  Test loss=1.0082, acc=79.9%
# 4280/5000: Train loss=0.0021, acc=100.0%  /  Test loss=0.9945, acc=80.3%
# 4300/5000: Train loss=0.0021, acc=100.0%  /  Test loss=0.9806, acc=80.6%
# 4320/5000: Train loss=0.0020, acc=100.0%  /  Test loss=0.9679, acc=80.9%
# 4340/5000: Train loss=0.0019, acc=100.0%  /  Test loss=0.9539, acc=81.1%
